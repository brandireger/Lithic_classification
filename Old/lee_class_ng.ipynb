# %%
import pandas as pd

lithic = pd.read_csv('Lithic_Database.csv')
lee = pd.read_csv('lee.csv')

# %%
# rename columns: replace R with lee, replace '.' with '_'
lee.columns = lee.columns.str.replace('R', 'lee').str.replace('.', '_')
# rename 'Unnamed: 0' to 'sample_no'
lee = lee.rename(columns={ lee.columns[0]: 'sample_no'})
lee.head()
# Out:
#    sample_no  lee1_2  lee2_2  lee3_2  lee4_2  lee5_2  lee1_3  lee2_3  lee3_3  \
# 0          1     2.0     NaN     2.0     2.0     2.0     1.0     NaN     1.0
# 1          2     2.0     2.0     2.0     2.0     2.0     1.0     1.0     1.0
# 2          3     2.0     2.0     2.0     2.0     2.0     1.0     1.0     1.0
# 3          4     2.0     2.0     NaN     2.0     2.0     1.0     1.0     NaN
# 4          5     2.0     2.0     2.0     2.0     2.0     1.0     1.0     1.0
#
#    lee4_3  ...  lee1_9  lee2_9  lee3_9  lee4_9  lee5_9  lee1_10  lee2_10  \
# 0     3.0  ...     8.0     NaN     7.0     7.0     3.0      7.0      NaN
# 1     3.0  ...     9.0     5.0     7.0     9.0     9.0      5.0      5.0
# 2     3.0  ...     8.0     3.0     7.0     7.0     3.0      7.0      9.0
# 3     3.0  ...     9.0     5.0     NaN     9.0     9.0      5.0      5.0
# 4     3.0  ...     9.0     5.0     7.0     9.0     9.0      5.0      5.0
#
#    lee3_10  lee4_10  lee5_10
# 0      7.0      7.0      7.0
# ...

# %%
# Replace all values with group_number
values = 'Group_' + lee.iloc[:, 1:].astype(str)
values.head()
# Out:
#       lee1_2     lee2_2     lee3_2     lee4_2     lee5_2     lee1_3  \
# 0  Group_2.0  Group_nan  Group_2.0  Group_2.0  Group_2.0  Group_1.0
# 1  Group_2.0  Group_2.0  Group_2.0  Group_2.0  Group_2.0  Group_1.0
# 2  Group_2.0  Group_2.0  Group_2.0  Group_2.0  Group_2.0  Group_1.0
# 3  Group_2.0  Group_2.0  Group_nan  Group_2.0  Group_2.0  Group_1.0
# 4  Group_2.0  Group_2.0  Group_2.0  Group_2.0  Group_2.0  Group_1.0
#
#       lee2_3     lee3_3     lee4_3     lee5_3  ...     lee1_9     lee2_9  \
# 0  Group_nan  Group_1.0  Group_3.0  Group_1.0  ...  Group_8.0  Group_nan
# 1  Group_1.0  Group_1.0  Group_3.0  Group_1.0  ...  Group_9.0  Group_5.0
# 2  Group_1.0  Group_1.0  Group_3.0  Group_1.0  ...  Group_8.0  Group_3.0
# 3  Group_1.0  Group_nan  Group_3.0  Group_1.0  ...  Group_9.0  Group_5.0
# 4  Group_1.0  Group_1.0  Group_3.0  Group_1.0  ...  Group_9.0  Group_5.0
#
#       lee3_9     lee4_9     lee5_9    lee1_10    lee2_10    lee3_10  \
# ...

# %%
lithic_cat = lithic['Category']
lithic_cat.head()
# Out:
# 0    Gravel Cherts
# 1    Gravel Cherts
# 2    Gravel Cherts
# 3    Gravel Cherts
# 4    Gravel Cherts
# Name: Category, dtype: object

# %%
# problem: NaN at end because of mismatch in index
values['category'] = lithic_cat
values.head()
# Out:
#       lee1_2     lee2_2     lee3_2     lee4_2     lee5_2     lee1_3  \
# 0  Group_2.0  Group_nan  Group_2.0  Group_2.0  Group_2.0  Group_1.0
# 1  Group_2.0  Group_2.0  Group_2.0  Group_2.0  Group_2.0  Group_1.0
# 2  Group_2.0  Group_2.0  Group_2.0  Group_2.0  Group_2.0  Group_1.0
# 3  Group_2.0  Group_2.0  Group_nan  Group_2.0  Group_2.0  Group_1.0
# 4  Group_2.0  Group_2.0  Group_2.0  Group_2.0  Group_2.0  Group_1.0
#
#       lee2_3     lee3_3     lee4_3     lee5_3  ...     lee2_9     lee3_9  \
# 0  Group_nan  Group_1.0  Group_3.0  Group_1.0  ...  Group_nan  Group_7.0
# 1  Group_1.0  Group_1.0  Group_3.0  Group_1.0  ...  Group_5.0  Group_7.0
# 2  Group_1.0  Group_1.0  Group_3.0  Group_1.0  ...  Group_3.0  Group_7.0
# 3  Group_1.0  Group_nan  Group_3.0  Group_1.0  ...  Group_5.0  Group_nan
# 4  Group_1.0  Group_1.0  Group_3.0  Group_1.0  ...  Group_5.0  Group_7.0
#
#       lee4_9     lee5_9    lee1_10    lee2_10    lee3_10    lee4_10  \
# ...

# %%
# add sample_no from lee to values
values['sample_no'] = lee['sample_no']
# move category column to front
cols = values.columns.tolist()
cols = cols[-2:] + cols[:-2]
values = values[cols]
# set index to first column
values = values.set_index('sample_no')
# save values as lee
lee = values
lee.head()
# Out:
#                 category     lee1_2     lee2_2     lee3_2     lee4_2  \
# sample_no
# 1          Gravel Cherts  Group_2.0  Group_nan  Group_2.0  Group_2.0
# 2          Gravel Cherts  Group_2.0  Group_2.0  Group_2.0  Group_2.0
# 3          Gravel Cherts  Group_2.0  Group_2.0  Group_2.0  Group_2.0
# 4          Gravel Cherts  Group_2.0  Group_2.0  Group_nan  Group_2.0
# 5          Gravel Cherts  Group_2.0  Group_2.0  Group_2.0  Group_2.0
#
#               lee5_2     lee1_3     lee2_3     lee3_3     lee4_3  ...  \
# sample_no                                                         ...
# 1          Group_2.0  Group_1.0  Group_nan  Group_1.0  Group_3.0  ...
# 2          Group_2.0  Group_1.0  Group_1.0  Group_1.0  Group_3.0  ...
# 3          Group_2.0  Group_1.0  Group_1.0  Group_1.0  Group_3.0  ...
# 4          Group_2.0  Group_1.0  Group_1.0  Group_nan  Group_3.0  ...
# 5          Group_2.0  Group_1.0  Group_1.0  Group_1.0  Group_3.0  ...
#
# ...

# %%
# lee1_2, lee2_2, lee3_2, lee4_2, lee5_2 are all same
lee1_2_cm = pd.crosstab(lee.category, lee.lee1_2)
# find the percentage of agreement between original categories vs largest count
lee1_2_cm['percentage'] = lee1_2_cm.max(axis=1) / lithic_cat.value_counts()
lee1_2_cm
# Out:
# lee1_2             Group_1.0  Group_2.0  Group_nan  percentage
# category
# Alibates                   0         19          4    0.826087
# EdwardsPC                  2         65          5    0.902778
# El Sauz Chert              0         57          5    0.919355
# El Sauz Chert Raw          5        242         33    0.864286
# Gravel Cherts              3        498         50    0.903811
# Gravel Cherts Raw          0         25          1    0.961538
# Knife River                0         10          2    0.833333
# Oman Chert                 0         16          5    0.761905

# %%
# lee1_3, lee2_3, lee3_3, lee4_3, lee5_3 are all same
lee1_3_cm = pd.crosstab(lee.category, lee.lee1_3)
# find the percentage of agreement between original categories vs largest count
lee1_3_cm['percentage'] = lee1_3_cm.max(axis=1) / lithic_cat.value_counts()
lee1_3_cm
# Out:
# lee1_3             Group_1.0  Group_2.0  Group_3.0  Group_nan  percentage
# category
# Alibates                  19          0          0          4    0.826087
# EdwardsPC                 66          0          1          5    0.916667
# El Sauz Chert             43         14          0          5    0.693548
# El Sauz Chert Raw        206         35          6         33    0.735714
# Gravel Cherts            496          2          3         50    0.900181
# Gravel Cherts Raw         23          2          0          1    0.884615
# Knife River                9          1          0          2    0.750000
# Oman Chert                16          0          0          5    0.761905

# %%
# lee1_4, lee2_4, lee3_4, lee4_4, lee5_4 are all same
lee1_4_cm = pd.crosstab(lee.category, lee.lee1_4)
# find the percentage of agreement between original categories vs largest count
lee1_4_cm['percentage'] = lee1_4_cm.max(axis=1) / lithic_cat.value_counts()
lee1_4_cm
# Out:
# lee1_4             Group_1.0  Group_2.0  Group_3.0  Group_4.0  Group_nan  \
# category
# Alibates                  19          0          0          0          4
# EdwardsPC                 66          0          1          0          5
# El Sauz Chert             43         14          0          0          5
# El Sauz Chert Raw        204         37          6          0         33
# Gravel Cherts            495          2          3          1         50
# Gravel Cherts Raw         23          2          0          0          1
# Knife River                9          0          0          1          2
# Oman Chert                 3          0          0         13          5
#
# lee1_4             percentage
# category
# Alibates             0.826087
# EdwardsPC            0.916667
# El Sauz Chert        0.693548
# El Sauz Chert Raw    0.728571
# Gravel Cherts        0.898367
# Gravel Cherts Raw    0.884615
# Knife River          0.750000
# Oman Chert           0.619048

# %%
# lee1_5, lee2_5, lee3_5, lee4_5, lee5_5 are all same
lee1_5_cm = pd.crosstab(lee.category, lee.lee1_5)
# find the percentage of agreement between original categories vs largest count
lee1_5_cm['percentage'] = lee1_5_cm.max(axis=1) / lithic_cat.value_counts()
lee1_5_cm
# Out:
# lee1_5             Group_1.0  Group_2.0  Group_3.0  Group_4.0  Group_5.0  \
# category
# Alibates                   0          0          0          0         19
# EdwardsPC                  0          0          1          0         66
# El Sauz Chert             14          0          0          0         43
# El Sauz Chert Raw         37          1          6          0        203
# Gravel Cherts              2          1          3          7        488
# Gravel Cherts Raw          2          0          0          0         23
# Knife River                0          1          0          0          9
# Oman Chert                 0         13          0          0          3
#
# lee1_5             Group_nan  percentage
# category
# Alibates                   4    0.826087
# EdwardsPC                  5    0.916667
# El Sauz Chert              5    0.693548
# El Sauz Chert Raw         33    0.725000
# Gravel Cherts             50    0.885662
# ...

# %%
# lee1_6, lee2_6, lee3_6, lee4_6, lee5_6 are all same
lee1_6_cm = pd.crosstab(lee.category, lee.lee1_6)
# find the percentage of agreement between original categories vs largest count
lee1_6_cm['percentage'] = lee1_6_cm.max(axis=1) / lithic_cat.value_counts()
lee1_6_cm
# Out:
# lee1_6             Group_1.0  Group_2.0  Group_3.0  Group_4.0  Group_5.0  \
# category
# Alibates                   0          0          1          0         18
# EdwardsPC                  0          0          0          9         57
# El Sauz Chert              0         14          1          0         42
# El Sauz Chert Raw          0         43          0          1        198
# Gravel Cherts              3          0          3          2        490
# Gravel Cherts Raw          0          0          2          0         23
# Knife River                0          1          0          0          9
# Oman Chert                12          0          0          0          4
#
# lee1_6             Group_6.0  Group_nan  percentage
# category
# Alibates                   0          4    0.782609
# EdwardsPC                  1          5    0.791667
# El Sauz Chert              0          5    0.677419
# El Sauz Chert Raw          5         33    0.707143
# ...

# %%
# lee1_7, lee2_7, lee3_7, lee4_7, lee5_7 are all same
lee1_7_cm = pd.crosstab(lee.category, lee.lee1_7)
# find the percentage of agreement between original categories vs largest count
lee1_7_cm['percentage'] = lee1_7_cm.max(axis=1) / lithic_cat.value_counts()
lee1_7_cm
# Out:
# lee1_7             Group_1.0  Group_2.0  Group_3.0  Group_4.0  Group_5.0  \
# category
# Alibates                   0          0          0          0         18
# EdwardsPC                  0          8          0          0         58
# El Sauz Chert              0          0         14          0         42
# El Sauz Chert Raw          0          1         46          0        195
# Gravel Cherts              8          2          0          1        483
# Gravel Cherts Raw          0          0          0          0         23
# Knife River                0          0          1          0          9
# Oman Chert                 0          0          0         12          4
#
# lee1_7             Group_6.0  Group_7.0  Group_nan  percentage
# category
# Alibates                   0          1          4    0.782609
# EdwardsPC                  1          0          5    0.805556
# El Sauz Chert              0          1          5    0.677419
# ...

# %%
# lee1_8, lee2_8, lee3_8, lee4_8, lee5_8 are all same
lee1_8_cm = pd.crosstab(lee.category, lee.lee1_8)
# find the percentage of agreement between original categories vs largest count
lee1_8_cm['percentage'] = lee1_8_cm.max(axis=1) / lithic_cat.value_counts()
lee1_8_cm
# Out:
# lee1_8             Group_1.0  Group_2.0  Group_3.0  Group_4.0  Group_5.0  \
# category
# Alibates                   1          0          5          2         11
# EdwardsPC                  0          0         30          0         35
# El Sauz Chert              0          0          8          1         34
# El Sauz Chert Raw          0          0         90          0        104
# Gravel Cherts              2          3        102          4        375
# Gravel Cherts Raw          0          0         14          2          9
# Knife River                0          0          6          0          3
# Oman Chert                 0         12          1          0          3
#
# lee1_8             Group_6.0  Group_7.0  Group_8.0  Group_nan  percentage
# category
# Alibates                   0          0          0          4    0.478261
# EdwardsPC                  0          0          2          5    0.486111
# ...

# %%
# lee1_9, lee2_9, lee3_9, lee4_9, lee5_9 are all same
lee1_9_cm = pd.crosstab(lee.category, lee.lee1_9)
# find the percentage of agreement between original categories vs largest count
lee1_9_cm['percentage'] = lee1_9_cm.max(axis=1) / lithic_cat.value_counts()
lee1_9_cm
# Out:
# lee1_9             Group_1.0  Group_2.0  Group_3.0  Group_4.0  Group_5.0  \
# category
# Alibates                   0          0          2          0          0
# EdwardsPC                  0          0          0          0          0
# El Sauz Chert              0          0          1          0          0
# El Sauz Chert Raw          0          0          0          0          0
# Gravel Cherts             12          3          3          1          1
# Gravel Cherts Raw          0          0          2          0          0
# Knife River                0          0          0          0          0
# Oman Chert                 0         12          0          0          0
#
# lee1_9             Group_6.0  Group_7.0  Group_8.0  Group_9.0  Group_nan  \
# category
# Alibates                   0          0          5         12          4
# EdwardsPC                  2          0         30         35          5
# ...

# %%
# lee1_10, lee2_10, lee3_10, lee4_10, lee5_10 are all same
lee1_10_cm = pd.crosstab(lee.category, lee.lee1_10)
# find the percentage of agreement between original categories vs largest count
lee1_10_cm['percentage'] = lee1_10_cm.max(axis=1) / lithic_cat.value_counts()
lee1_10_cm
# Out:
# lee1_10            Group_1.0  Group_10.0  Group_2.0  Group_3.0  Group_4.0  \
# category
# Alibates                   0           0          0          2          0
# EdwardsPC                  0           0          0          0          8
# El Sauz Chert              0           0          0          1          0
# El Sauz Chert Raw          0           0          0          1          0
# Gravel Cherts             11           1          4          4          0
# Gravel Cherts Raw          0           0          0          2          0
# Knife River                0           0          0          0          0
# Oman Chert                 0           0         13          0          0
#
# lee1_10            Group_5.0  Group_6.0  Group_7.0  Group_8.0  Group_9.0  \
# category
# Alibates                  11          0          6          0          0
# EdwardsPC                 35          0         22          2          0
# ...
